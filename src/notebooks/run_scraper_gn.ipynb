# %%
import os
os.chdir(r"D:\Studying\UoR\1. Data Mining\Final_Project")

# %% [markdown]
# # Global News Scraper

# %%
from src.scrapers.gn_scraper import GNScraper

# %%
url_scraper = GNScraper(pause_min=5, pause_max=10)
url_scraper.get_urls()
# Out:
# [00h 00m 17s] Total saved so far: 60
# Load More button moved.
# [00h 00m 41s] Total saved so far: 60
# Load More button moved.
# [00h 01m 01s] Total saved so far: 60
# Load More button moved.
# [00h 01m 29s] Total saved so far: 80
# Load More button moved.
# [00h 01m 53s] Total saved so far: 100
# Load More button moved.
# [00h 02m 21s] Total saved so far: 120
# Load More button moved.
# [00h 02m 40s] Total saved so far: 140
# Load More button moved.
# [00h 03m 04s] Total saved so far: 160
# Load More button moved.
# [00h 03m 31s] Total saved so far: 180
# Load More button moved.
# [00h 03m 52s] Total saved so far: 199
# Load More button moved.
# [00h 04m 21s] Total saved so far: 219
# Load More button moved.
# [00h 04m 44s] Total saved so far: 239
# Load More button moved.
# [00h 05m 12s] Total saved so far: 259
# Load More button moved.
# [00h 05m 37s] Total saved so far: 279
# Load More button moved.
# [00h 06m 04s] Total saved so far: 299
# Load More button moved.
# ...
