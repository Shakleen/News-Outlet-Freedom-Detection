# %%
import os
os.chdir(r"../../../")

# %% [markdown]
# # Reuters Scraper

# %%
from src.scrapers.reuters_scraper import ReutersScraper

# %%
url_scraper = ReutersScraper(search_term="canada", pause_min=3, pause_max=5, total=1e4)
url_scraper.get_urls()
# Out:
# Exception trying to discover chromedriver version: error sending request for url (https://googlechromelabs.github.io/chrome-for-testing/known-good-versions-with-downloads.json): connection error: connection reset
# [00h 00m 13s] Total saved so far: 10
# [00h 00m 20s] Total saved so far: 10
# [00h 00m 30s] Total saved so far: 20
# [00h 00m 41s] Total saved so far: 30
# [00h 00m 51s] Total saved so far: 40
# [00h 01m 03s] Total saved so far: 50
# [00h 01m 14s] Total saved so far: 60
# [00h 01m 26s] Total saved so far: 70
# [00h 01m 37s] Total saved so far: 80
# [00h 01m 49s] Total saved so far: 90
# [00h 02m 01s] Total saved so far: 100
# [00h 02m 12s] Total saved so far: 110
# [00h 02m 22s] Total saved so far: 120
# [00h 02m 34s] Total saved so far: 130
# [00h 02m 44s] Total saved so far: 140
# [00h 02m 54s] Total saved so far: 150
# [00h 03m 02s] Total saved so far: 160
# [00h 03m 11s] Total saved so far: 170
# [00h 03m 20s] Total saved so far: 180
# ...
