# %% [markdown]
# # Topic Modeling with BERTopic
#
# Guide: [Best Practices](https://maartengr.github.io/BERTopic/getting_started/best_practices/best_practices.html#data)

# %%
# %%capture
# %pip install bertopic scikit-learn spacy nltk

# %%
import os
import pandas as pd

# BERTopic Imports
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from bertopic import BERTopic

# %% [markdown]
# ## Loading Data

# %%
ROOT_PATH = r"/content/drive/MyDrive/News Data"

CANADA_FILE_PATH = os.path.join(ROOT_PATH, "canada.csv")
CHINA_FILE_PATH = os.path.join(ROOT_PATH, "china.csv")
RUSSIA_FILE_PATH = os.path.join(ROOT_PATH, "russia.csv")

INF_ROOT_PATH = r"/content/drive/MyDrive/News Data/llama2_inference_data"
INFERENCE_CANADA_FILE_PATH = os.path.join(INF_ROOT_PATH, "answer_canada.csv")
INFERENCE_CHINA_FILE_PATH = os.path.join(INF_ROOT_PATH, "answer_china.csv")
INFERENCE_RUSSIA_FILE_PATH = os.path.join(INF_ROOT_PATH, "answer_russia.csv")

# %%
df_canada = pd.read_csv(CANADA_FILE_PATH, usecols=["maintext"])
df_china = pd.read_csv(CHINA_FILE_PATH, usecols=["maintext"])
df_russia = pd.read_csv(RUSSIA_FILE_PATH, usecols=["maintext"])

# %% [markdown]
# ## Common Elements

# %% [markdown]
# ### Preventing Stochastic Behavior
#
# In BERTopic, we generally use a dimensionality reduction algorithm to reduce the size of the embeddings. This is done to prevent the curse of dimensionality to a certain degree.
#
# As a default, this is done with UMAP which is an incredible algorithm for reducing dimensional space.

# %%
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0,
                  metric='cosine', random_state=42)

# %% [markdown]
# ### Controlling Number of Topics
#
# There is a parameter to control the number of topics, namely nr_topics. This parameter, however, merges topics after they have been created. It is a parameter that supports creating a fixed number of topics.
#
# However, it is advised to control the number of topics through the cluster model which is by default HDBSCAN. HDBSCAN has a parameter, namely `min_cluster_size` that indirectly controls the number of topics that will be created.
#
# A higher `min_cluster_size` will generate fewer topics and a lower `min_cluster_size` will generate more topics.

# %%
hdbscan_model = HDBSCAN(min_cluster_size=150, metric='euclidean',
                        cluster_selection_method='eom',
                        prediction_data=True)

# %% [markdown]
# ### Improving Default Representation

# %%
vectorizer_model = CountVectorizer(stop_words="english",
                                   min_df=0.01, max_df=0.9,
                                   ngram_range=(1, 3))

# %% [markdown]
# ## Canada

# %% [markdown]
# ### Pre-calculate embeddings
#
# BERTopic works by converting documents into numerical values, called embeddings. This process can be very costly, especially if we want to iterate over parameters. Instead, we can calculate those embeddings once and feed them to BERTopic to skip calculating embeddings each time.

# %%
embedding_model = SentenceTransformer("all-MiniLM-L12-v2")
embeddings = embedding_model.encode(df_canada.maintext, show_progress_bar=True)
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/393 [00:00<?, ?it/s]

# %% [markdown]
# ### Training

# %%
topic_model = BERTopic(
  nr_topics = "auto",

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  vectorizer_model=vectorizer_model,

  # Settings
  language = 'english',
  calculate_probabilities = True,

  # Hyperparameters
  top_n_words=25,
  verbose=True
)

# Train model
topics, probs = topic_model.fit_transform(df_canada.maintext, embeddings)
# Out:
# 2023-12-04 01:12:55,654 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-04 01:13:24,893 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 01:13:24,895 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-04 01:13:26,552 - BERTopic - Cluster - Completed ✓
# 2023-12-04 01:13:26,553 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-04 01:14:19,995 - BERTopic - Representation - Completed ✓
# 2023-12-04 01:14:20,137 - BERTopic - Topic reduction - Reducing number of topics
# 2023-12-04 01:15:15,214 - BERTopic - Topic reduction - Reduced number of topics from 20 to 12

# %% [markdown]
# Setting Custom Labels

# %%
for topic in range(-1, 11):
  print(f"Topic {topic+2}: " + ", ".join(topic_model.get_topic_info(topic)["Representation"][0]))
# Out:
# Topic 1: india, israel, gaza, hamas, smoke, sikh, indian, violence, air quality, asylum, justice, mercedes, israeli, cancer, ai, hurricane, stephenson, mercedes stephenson, bank canada, crime, refugees, hate, nijjar, allegations, young
# Topic 2: fires, officers, firefighters, residential, crime, fireworks, lake, evacuation, sexual, murder, police said, forest, justice, music, victims, violence, smoke, gender, reconciliation, river, young, hospital, residential school, crews, shooting
# Topic 3: ukraine, chinese, interference, bank canada, carbon, emissions, foreign interference, basis points, russian, central bank, canadian dollar, pipeline, trading, inquiry, national security, macklem, cents, allegations, greenback, exports, bond, defence, yields, hike, csis
# Topic 4: cup, hockey, win, world cup, league, coach, womens, tournament, soccer, scored, knights, sport, sports, championship, olympic, fans, medal, mens, athletes, football, jets, nhl, hockey canada, ice, olympics
# Topic 5: drug, patients, health canada, vaccine, cannabis, drugs, hospital, dr, public health, doctors, ozempic, disease, diabetes, symptoms, vaccines, blood, nurses, doctor, flu, virus, overdose, infection, hiv, hospitals, cancer
# Topic 6: tsx, composite, cents, tsx composite, composite index, tsx composite index, stock index, main stock, stocks, main stock index, toronto stock, toronto stock exchange, stock exchange, exchange tsx composite, exchange tsx, stock exchange tsx, exchange, canada main, canada main stock, barrel, federal reserve, reserve, crude, copper, metals
# Topic 7: snow, environment canada, temperatures, flooding, rainfall, freezing, snowfall, winds, temperature, cold, mm, thunderstorm, hail, ice, weather agency, river, thunderstorms, freezing rain, meteorologist, canada issued, environment canada said, environment canada issued, precipitation, flood, centimetres
# Topic 8: units, rent, mortgage, buyers, affordable housing, housing market, affordability, rentals, bedroom, housing crisis, airbnb, apartment, rents, homelessness, cmhc, listings, afford, home prices, renters, zoning, tenants, term rental, shelter, sellers, housing units
# Topic 9: grocery, grocers, food bank, food banks, restaurant, food prices, food inflation, poverty, loblaw, nordstrom, meat, farmers, insecurity, zellers, food insecurity, charlebois, dairy, retailers, grocery store, sugar, beef, foods, brands, walmart, chicken
# Topic 10: air canada, westjet, airport, airline, pilots, passengers, passenger, aircraft, pilot, plane, aviation, flair, travellers, airports, carrier, international airport, planes, carriers, passenger rights, fly, air passenger, sunwing, crash, swoop, cancellations
# Topic 11: meta, content, wireless, shaw, ttc, telus, users, subway, giants, publishers, carriers, online news, instagram, crtc, 5g, advertising, champagne, facebook instagram, telecom, telecommunications, freedom, news act, online news act, news content, merger
# Topic 12: psac, bargaining, unifor, wage, public service, cra, seaway, picket, public service alliance, service alliance, treasury board, tentative, ford, remote work, service alliance canada, gm, alliance canada, grain, treasury, collective, payne, revenue agency, aylward, servants, striking

# %%
topic_model.set_topic_labels({-1: "conflict",
                              0: "crime",
                              1: "national-security",
                              2: "sports",
                              3: "health",
                              4: "finance",
                              5: "weather",
                              6: "housing",
                              7: "food",
                              8: "transportation",
                              9: "telecommunications",
                              10: "public-service"})

# %%
topic_model.visualize_topics(custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d7e38763-6e4d-43e0-a305-f1ab489291a0" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7e38763-6e4d-43e0-a305-f1ab489291a0")) {                    Plotly.newPlot(                        "d7e38763-6e4d-43e0-a305-f1ab489291a0",                        [{"customdata":[[0,"crime",2659],[1,"national-security",2010],[2,"sports",1024],[3,"health",677],[4,"finance",639],[5,"weather",500],[6,"housing",422],[7,"food",298],[8,"transportation",298],[9,"telecommunications",187],[10,"public-service",172]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[2659,2010,1024,677,639,500,422,298,298,187,172],"sizemode":"area","sizeref":1.661875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18.01225471496582,18.33953285217285,17.53035545349121,18.698183059692383,17.823896408081055,18.113805770874023,17.413686752319336,16.119672775268555,18.314348220825195,17.71551513671875,15.881173133850098],"xaxis":"x","y":[-4.905755996704102,-2.1132428646087646,-4.66817045211792,-5.072681903839111,-2.2402572631835938,-5.461480617523193,-2.862647294998169,-2.0543293952941895,-4.464661121368408,-1.683414340019226,-3.0830352306365967],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222, ...

# %%
topic_model.visualize_hierarchy(custom_labels=True, width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="47a9fb88-6bb8-4efe-8acf-50e715915e3f" class="plotly-graph-div" style="height:365px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47a9fb88-6bb8-4efe-8acf-50e715915e3f")) {                    Plotly.newPlot(                        "47a9fb88-6bb8-4efe-8acf-50e715915e3f",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9529185149005079,0.9529185149005079,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9700945211860968,0.9700945211860968,0.9529185149005079],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9552839230954385,0.9552839230954385,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7872377853214025,0.7872377853214025,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8791626869839128,0.8791626869839128,0.7872377853214025],"xaxis":"x","y":[-55.0,-55.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8791626869839128,0.8949252604443476,0.8949252604443476,0.0],"xaxis":"x","y":[-62.5,-62.5,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8949252604443476,0.9166625593933538,0.9166625593933538,0.0],"xaxis":"x","y":[-73.75,-73.75,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9552839230954385,0.9724990807770608,0.9724990807770608,0.9166625593933538],"xaxis":"x","y":[-40.0,-40.0,-84.375,-84.375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9724990807770608,0.9980621641850994,0.9980621641850994,0.0],"xaxis":"x","y":[-62.1875,-62.1875,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9700945211860968,1.007565342047145,1.007565342047145,0.9980621641850994],"xaxis":"x","y":[-12.5,-12.5,-83.59375,-83.59375],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":365,"hovermode":"closest","showlegend":false,"width":600,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["telecommunications","transportation","public-service","weather","sports","health","crime","national-security","housing","food","finance"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0,-85.0,-95.0,-105.0],"type":"linear","zeroline":false,"range":[-110.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carp ...

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                             Name  \
# 0      -1   3680                       -1_india_israel_gaza_hamas
# 1       0   2659        0_fires_officers_firefighters_residential
# 2       1   2010       1_ukraine_chinese_interference_bank canada
# 3       2   1024                       2_cup_hockey_win_world cup
# 4       3    677            3_drug_patients_health canada_vaccine
# 5       4    639              4_tsx_composite_cents_tsx composite
# 6       5    500  5_snow_environment canada_temperatures_flooding
# 7       6    422                     6_units_rent_mortgage_buyers
# 8       7    298           7_grocery_grocers_food bank_food banks
# 9       8    298             8_air canada_westjet_airport_airline
# 10      9    187                     9_meta_content_wireless_shaw
# 11     10    172                   10_psac_bargaining_unifor_wage
#
#                                        Representation  \
# 0   [india, israel, gaza, hamas, smoke, sikh, indi...
# 1   [fires, officers, firefighters, residential, c...
# 2   [ukraine, chinese, interference, bank canada, ...
# 3   [cup, hockey, win, world cup, league, coach, w...
# 4   [drug, patients, health canada, vaccine, canna...
# 5   [tsx, composite, cents, tsx composite, composi...
# 6   [snow, environment canada, temperatures, flood...
# 7   [units, rent, mortgage, buyers, affordable hou...
# 8   [grocery, grocers, food bank, food banks, rest...
# 9   [air canada, westjet, airport, airline, pilots...
# 10  [meta, content, wireless, shaw, ttc, telus, us...
# 11  [psac, bargaining, unifor, wage, public servic...
#
#                                   Representative_Docs
# 0   [Allegations that there is evidence that agent...
# 1   [After a cool-weather reprieve, wildfire condi...
# 2   [The Canadian dollar weakened to a near two-we...
# 3   [The FIFA Womens World Cup is already setting ...
# 4   [With the arrival of the latest COVID-19 varia...
# 5   [Canadas main stock index stepped lower Wednes...
# 6   [Environment Canada has issued a snowfall warn...
# 7   [Canadian renters have a tough few years in st...
# 8   [Whether youre catching a flight, opening a ne...
# 9   [WestJet is scrambling to restart more than 20...
# 10  [Rogers Communications Inc. has rolled out its...
# 11  [More than 155,000 public service workers are ...

# %%
topic_model.visualize_heatmap(custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ff141d4d-c275-4869-a323-2bc5ea9fee52" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff141d4d-c275-4869-a323-2bc5ea9fee52")) {                    Plotly.newPlot(                        "ff141d4d-c275-4869-a323-2bc5ea9fee52",                        [{"coloraxis":"coloraxis","name":"0","x":["crime","national-security","sports","health","finance","weather","housing","food","transportation","telecommunications","public-service"],"y":["crime","national-security","sports","health","finance","weather","housing","food","transportation","telecommunications","public-service"],"z":[[1.0,0.6697049841478145,0.6055157799418263,0.6603989090687681,0.4116806955340027,0.6533126214952676,0.6089885543504994,0.5706609274515125,0.5933244937179447,0.5162114459022932,0.5806729026404267],[0.6697049841478145,1.0000000000000002,0.5000397654532641,0.6022493142148215,0.5994342974876681,0.4738313361442694,0.6187292630683838,0.6327677070683175,0.5218831534698946,0.622975322194071,0.5948562767245535],[0.6055157799418263,0.5000397654532641,1.0000000000000002,0.41916704425878915,0.3047512464064989,0.41025139355176626,0.35544942325968454,0.38079855457969614,0.48184209348917123,0.3597986239966785,0.42979599724781564],[0.6603989090687681,0.6022493142148215,0.41916704425878915,1.0000000000000004,0.32196465250723055,0.4561923378806497,0.5382432859322221,0.5735107793853346,0.4980175256315139,0.4968335507904086,0.4839118993640942],[0.4116806955340027,0.5994342974876681,0.3047512464064989,0.32196465250723055,1.0000000000000007,0.37220004897009284,0.44220049055261357,0.42509654116210277,0.34368570770653417,0.3854441206042629,0.3461254819482522],[0.6533126214952676,0.4738313361442694,0.41025139355176626,0.4561923378806497,0.37220004897009284,1.0000000000000009,0.5165480426153604,0.3913008435347079,0.45246850193629184,0.3491127528365518,0.36241482402759784],[0.6089885543504994,0.6187292630683838,0.35544942325968454,0.5382432859322221,0.44220049055261357,0.5165480426153604,1.0000000000000009,0.5736093867360988,0.415783468784759,0.48405352065127993,0.48004353556457136],[0.5706609274515125,0.6327677070683175,0.38079855457969614,0.5735107793853346,0.42509654116210277,0.3913008435347079,0.5736093867360988,1.0000000000000009,0.4381530004243208,0.5360493091272155,0.5231995019086944],[0.5933244937179447,0.5218831534698946,0.48184209348917123,0.4980175256315139,0.34368570770653417,0.45246850193629184,0.415783468784759,0.4381530004243208,1.0000000000000016,0.5173336421520631,0.5238118068205908],[0.5162114459022932,0.622975322194071,0.3597986239966785,0.4968335507904086,0.3854441206042629,0.3491127528365518,0.48405352065127993,0.5360493091272155,0.5173336421520631,1.0000000000000009,0.5108546294602477],[0.5806729026404267,0.5948562767245535,0.42979599724781564,0.4839118993640942,0.3461254819482522,0.36241482402759784,0.48004353556457136,0.5231995019086944,0.5238118068205908,0.5108546294602477,1.0000000000000004]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0. ...

# %% [markdown]
# ### Inference

# %%
df = pd.read_csv(INFERENCE_CANADA_FILE_PATH)

# %%
x = topic_model.transform(df.maintext)
# Out:
# Batches:   0%|          | 0/125 [00:00<?, ?it/s]
# 2023-12-04 01:28:09,553 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2023-12-04 01:28:27,242 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 01:28:27,243 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2023-12-04 01:28:27,610 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2023-12-04 01:28:28,416 - BERTopic - Probabilities - Completed ✓
# 2023-12-04 01:28:28,417 - BERTopic - Cluster - Completed ✓

# %%
df["topic"] = [topic_model.get_topic_info(i).CustomName[0] for i in x[0]]

# %%
df.topic.value_counts()
# Out:
# national-security     1079
# conflict              1042
# crime                  505
# finance                423
# sports                 378
# health                 125
# housing                 92
# weather                 81
# telecommunications      79
# transportation          76
# food                    73
# public-service          47
# Name: topic, dtype: int64

# %%
df.to_csv(INFERENCE_CANADA_FILE_PATH, index=False)

# %%
del df_canada, df, topic_model, embeddings, x

# %% [markdown]
# ## China

# %%
embedding_model = SentenceTransformer("all-MiniLM-L12-v2")
embeddings = embedding_model.encode(df_china.maintext, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/312 [00:00<?, ?it/s]

# %% [markdown]
# ### Training

# %%
topic_model = BERTopic(
  nr_topics = "auto",

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  vectorizer_model=vectorizer_model,

  # Settings
  language = 'english',
  calculate_probabilities = True,

  # Hyperparameters
  top_n_words=25,
  verbose=True
)

# Train model
topics, probs = topic_model.fit_transform(df_china.maintext, embeddings)
# Out:
# 2023-12-04 01:30:30,359 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-04 01:30:50,400 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 01:30:50,402 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-04 01:30:51,568 - BERTopic - Cluster - Completed ✓
# 2023-12-04 01:30:51,569 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-04 01:31:21,611 - BERTopic - Representation - Completed ✓
# 2023-12-04 01:31:21,694 - BERTopic - Topic reduction - Reducing number of topics
# 2023-12-04 01:31:51,672 - BERTopic - Topic reduction - Reduced number of topics from 11 to 11

# %% [markdown]
# Setting Custom Labels

# %%
for topic in range(-1, 10):
  print(f"Topic {topic+2}: " + ", ".join(topic_model.get_topic_info(topic)["Representation"][0]))
# Out:
# Topic 1: cpc, india, central committee, dollar, brics, cultural, developing, japanese, civil, xiongan, midpoint, standing committee, new area, han, climate change, xi said, peace, space, carbon, offshore, australia, fugitives, increase, cpc central, european
# Topic 2: cpc, central committee, cpc central, cpc central committee, standing committee, governance, npc, national congress, cppcc, 19th, national committee, socialism, political bureau, china cpc, era, general secretary, party china cpc, xi said, socialism chinese, socialism chinese characteristics, new era, democracy, discipline, people congress, socialist
# Topic 3: russia, peace, china sea, south china sea, exchanges, xi said, asean, ukraine, mutual, russian, dialogue, partnership, prime, prime minister, putin, foreign minister, philippines, nuclear, friendship, vietnam, blinken, islands, africa, philippine, chinese president
# Topic 4: li said, keqiang, li keqiang, premier li keqiang, increase, central bank, bonds, logistics, guideline, year year, reforms, costs, technologies, business environment, bond, central committee, percent year, border, foreign investment, stimulus, lending, retail, bank china, technological, economic recovery
# Topic 5: poverty, grain, alleviation, poverty alleviation, farmers, poor, village, agriculture rural, wheat, rice, farmland, vitalization, impoverished, harvest, rural vitalization, food security, villages, rural affairs, crops, increase, poverty relief, hectares, residents, agriculture rural affairs, soil
# Topic 6: care, patients, drugs, healthcare, epidemic, hospitals, diseases, pension, hospital, population, elderly, children, tcm, vaccine, basic, national health, vaccines, outbreak, health commission, public health, wuhan, medicine, coronavirus, guideline, medicines
# Topic 7: discipline, bribes, cpc, discipline inspection, commission discipline inspection, commission discipline, central commission discipline, expelled, central commission, graft, procuratorate, ccdi, intermediate, intermediate people, intermediate people court, people court, suspected, taking bribes, prosecutors, bribery, supervisory, supervisory commission, anti graft, positions, accepting
# Topic 8: imports, tons, crude, metric, bpd, metric tons, refiners, australian, million metric, million metric tons, gas, million bpd, shipments, australia, copper, russia, fuel, tonnes, million tons, barley, data showed, diesel, russian, million tonnes, chip
# Topic 9: pollution, river, ecological, environmental protection, forest, yangtze, ecology, carbon, conservation, fishing, air pollution, park, yangtze river, ecology environment, green, basin, air quality, parks, lake, wetlands, national park, pollutants, forestry, ministry ecology, ministry ecology environment
# Topic 10: index, hang seng, hang, seng, blue chip, composite, hang seng index, seng index, shanghai composite, composite index, chip, shanghai composite index, blue, china blue chip, china blue, csi, sentiment, csi 300, benchmark, enterprises index, china enterprises index, china enterprises, dropped, csi 300 index, 300 index
# Topic 11: party chief, cpc, provincial committee, standing committee, mayor, served, central committee, deputy head, elected, deputy party, vice minister, native, municipal, party secretary, secretary cpc, nominated, removed post, replacing, appointed deputy, people congress, municipal committee, posts, deputy party chief, cpc central, cpc central committee

# %%
topic_model.set_topic_labels({-1: "politics",
                              0: "politics",
                              1: "international-relations",
                              2: "finance",
                              3: "agriculture",
                              4: "healthcare",
                              5: "politics",
                              6: "finance",
                              7: "environment",
                              8: "finance",
                              9: "politics"})

# %%
topic_model.visualize_topics(custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="79fa4ebc-8c4f-4a2b-b9c8-7fb68717a630" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79fa4ebc-8c4f-4a2b-b9c8-7fb68717a630")) {                    Plotly.newPlot(                        "79fa4ebc-8c4f-4a2b-b9c8-7fb68717a630",                        [{"customdata":[[0,"politics",2698],[1,"international-relations",1625],[2,"finance",1210],[3,"agriculture",427],[4,"healthcare",385],[5,"politics",248],[6,"finance",223],[7,"environment",207],[8,"finance",167],[9,"politics",153]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[2698,1625,1210,427,385,248,223,207,167,153],"sizemode":"area","sizeref":1.68625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[10.368451118469238,10.884500503540039,8.582880973815918,7.9580535888671875,9.092155456542969,-7.855632781982422,8.473431587219238,7.8715715408325195,9.015506744384766,-7.514568328857422],"xaxis":"x","y":[16.274599075317383,16.543560028076172,16.04643440246582,16.470277786254883,15.867403984069824,7.382246017456055,15.4638032913208,16.81414222717285,16.501359939575195,7.04119348526001],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e ...

# %%
topic_model.visualize_hierarchy(custom_labels=True, width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2670b2b8-a312-49e2-ba80-8b806e1dbab9" class="plotly-graph-div" style="height:350px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2670b2b8-a312-49e2-ba80-8b806e1dbab9")) {                    Plotly.newPlot(                        "2670b2b8-a312-49e2-ba80-8b806e1dbab9",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9203789281974661,0.9203789281974661,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.820057537261824,0.820057537261824,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6638820381906883,0.6638820381906883,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.6638820381906883,0.743975949109496,0.743975949109496,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7995871644422958,0.7995871644422958,0.743975949109496],"xaxis":"x","y":[-45.0,-45.0,-67.5,-67.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.820057537261824,0.8744649640037205,0.8744649640037205,0.7995871644422958],"xaxis":"x","y":[-30.0,-30.0,-56.25,-56.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.7630347468946667,0.7630347468946667,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8744649640037205,1.073565103019806,1.073565103019806,0.7630347468946667],"xaxis":"x","y":[-43.125,-43.125,-90.0,-90.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9203789281974661,1.098049815690961,1.098049815690961,1.073565103019806],"xaxis":"x","y":[-10.0,-10.0,-66.5625,-66.5625],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":350,"hovermode":"closest","showlegend":false,"width":600,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["finance","finance","environment","agriculture","healthcare","politics","finance","international-relations","politics","politics"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0,-85.0,-95.0],"type":"linear","zeroline":false,"range":[-100.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   2641              -1_cpc_india_central committee_dollar
# 1       0   2698  0_cpc_central committee_cpc central_cpc centra...
# 2       1   1625           1_russia_peace_china sea_south china sea
# 3       2   1210    2_li said_keqiang_li keqiang_premier li keqiang
# 4       3    427    3_poverty_grain_alleviation_poverty alleviation
# 5       4    385                   4_care_patients_drugs_healthcare
# 6       5    248      5_discipline_bribes_cpc_discipline inspection
# 7       6    223                        6_imports_tons_crude_metric
# 8       7    207  7_pollution_river_ecological_environmental pro...
# 9       8    167                        8_index_hang seng_hang_seng
# 10      9    153  9_party chief_cpc_provincial committee_standin...
#
#                  CustomName  \
# 0                  politics
# 1                  politics
# 2   international-relations
# 3                   finance
# 4               agriculture
# 5                healthcare
# 6                  politics
# 7                   finance
# 8               environment
# 9                   finance
# 10                 politics
#
#                                        Representation  \
# 0   [cpc, india, central committee, dollar, brics,...
# 1   [cpc, central committee, cpc central, cpc cent...
# 2   [russia, peace, china sea, south china sea, ex...
# 3   [li said, keqiang, li keqiang, premier li keqi...
# 4   [poverty, grain, alleviation, poverty alleviat...
# 5   [care, patients, drugs, healthcare, epidemic, ...
# 6   [discipline, bribes, cpc, discipline inspectio...
# 7   [imports, tons, crude, metric, bpd, metric ton...
# 8   [pollution, river, ecological, environmental p...
# 9   [index, hang seng, hang, seng, blue chip, comp...
# 10  [party chief, cpc, provincial committee, stand...
#
#                                   Representative_Docs
# 0   [China's yuan firmed to a three-week high agai...
# 1   [Huang Kunming, a member of the Political Bure...
# 2   [The course of events in the year since the la...
# 3   [China will consolidate and expand its economi...
# 4   [With Xi Jinping in charge, China's poverty-re...
# 5   [Premier says changes will be good for public ...
# 6   [Yang Keqin. Yang Keqin, former chief procurat...
# 7   [China's imports of major commodities lost mom...
# 8   [A total of 5,500 Chinese sturgeons are releas...
# 9   [China stocks closed lower on Tuesday after a ...
# 10  [Zhang Qingwei no longer concurrently serves a...

# %%
topic_model.visualize_heatmap(custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b096f5fd-6b45-4cee-9552-ce0cb19839a0" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b096f5fd-6b45-4cee-9552-ce0cb19839a0")) {                    Plotly.newPlot(                        "b096f5fd-6b45-4cee-9552-ce0cb19839a0",                        [{"coloraxis":"coloraxis","name":"0","x":["politics","international-relations","finance","agriculture","healthcare","politics","finance","environment","finance","politics"],"y":["politics","international-relations","finance","agriculture","healthcare","politics","finance","environment","finance","politics"],"z":[[1.0000000000000004,0.7873129222956448,0.8049552356560248,0.6684691237107543,0.7458174891204297,0.7385798173571441,0.5334607444877201,0.7143189714678172,0.42990135198439483,0.7827228272902892],[0.7873129222956448,1.0000000000000004,0.7552695281786048,0.6006940954685721,0.6367295633248005,0.5760049953465524,0.6248402873326131,0.6082320473828202,0.4331830925915934,0.6954527462232785],[0.8049552356560248,0.7552695281786048,1.0000000000000004,0.7633754647247211,0.7588092309508767,0.5652097691747481,0.7504465091035901,0.7483448100979431,0.5747565329455688,0.6627417373590954],[0.6684691237107543,0.6006940954685721,0.7633754647247211,1.000000000000001,0.6794172915018378,0.4861042239480382,0.6252347320834544,0.7491512901023134,0.4458156270883449,0.5735290930868018],[0.7458174891204297,0.6367295633248005,0.7588092309508767,0.6794172915018378,1.0000000000000004,0.5234935490218995,0.570298835838801,0.6938747803671358,0.4156008536459762,0.5876862167980805],[0.7385798173571441,0.5760049953465524,0.5652097691747481,0.4861042239480382,0.5234935490218995,1.0000000000000016,0.39475858670970454,0.5433305217540259,0.39091512433547276,0.8157744469240993],[0.5334607444877201,0.6248402873326131,0.7504465091035901,0.6252347320834544,0.570298835838801,0.39475858670970454,1.0000000000000009,0.6205374633147442,0.5517888615354969,0.4059759790181584],[0.7143189714678172,0.6082320473828202,0.7483448100979431,0.7491512901023134,0.6938747803671358,0.5433305217540259,0.6205374633147442,1.0000000000000004,0.3999522764500474,0.6027414535387113],[0.42990135198439483,0.4331830925915934,0.5747565329455688,0.4458156270883449,0.4156008536459762,0.39091512433547276,0.5517888615354969,0.3999522764500474,1.0000000000000009,0.4094842394233923],[0.7827228272902892,0.6954527462232785,0.6627417373590954,0.5735290930868018,0.5876862167980805,0.8157744469240993,0.4059759790181584,0.6027414535387113,0.4094842394233923,1.0000000000000002]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...

# %% [markdown]
# ### Inference

# %%
df = pd.read_csv(INFERENCE_CHINA_FILE_PATH)

# %%
x = topic_model.transform(df.maintext)
# Out:
# Batches:   0%|          | 0/125 [00:00<?, ?it/s]
# 2023-12-04 01:38:50,926 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2023-12-04 01:38:55,051 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 01:38:55,052 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2023-12-04 01:38:55,422 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2023-12-04 01:38:56,165 - BERTopic - Probabilities - Completed ✓
# 2023-12-04 01:38:56,166 - BERTopic - Cluster - Completed ✓

# %%
df["topic"] = [topic_model.get_topic_info(i).CustomName[0] for i in x[0]]

# %%
df.topic.value_counts()
# Out:
# politics                   2034
# finance                     860
# international-relations     841
# agriculture                 113
# healthcare                  111
# environment                  41
# Name: topic, dtype: int64

# %%
df.to_csv(INFERENCE_CHINA_FILE_PATH, index=False)

# %%
del df_china, df, topic_model, embeddings, x

# %% [markdown]
# ## Russia

# %%
embedding_model = SentenceTransformer("all-MiniLM-L12-v2")
embeddings = embedding_model.encode(df_russia.maintext, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/503 [00:00<?, ?it/s]

# %% [markdown]
# ### Training

# %%
topic_model = BERTopic(
  nr_topics = 11,

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  vectorizer_model=vectorizer_model,

  # Settings
  language = 'english',
  calculate_probabilities = True,

  # Hyperparameters
  top_n_words=10,
  verbose=True
)

# Train model
topics, probs = topic_model.fit_transform(df_russia.maintext, embeddings)
# Out:
# 2023-12-04 01:49:49,118 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-04 01:50:02,543 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 01:50:02,545 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-04 01:50:04,608 - BERTopic - Cluster - Completed ✓
# 2023-12-04 01:50:04,609 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-04 01:50:47,468 - BERTopic - Representation - Completed ✓
# 2023-12-04 01:50:47,590 - BERTopic - Topic reduction - Reducing number of topics
# 2023-12-04 01:50:47,592 - BERTopic - Topic reduction - Reduced number of topics from 7 to 7

# %% [markdown]
# Setting Custom Labels

# %%
for topic in range(-1, 6):
  print(f"Topic {topic+2}: " + ", ".join(topic_model.get_topic_info(topic)["Representation"][0]))
# Out:
# Topic 1: yandex, court, griner, witnesses, jehovahs, iss, roscosmos, moon, jehovahs witnesses, calvey
# Topic 2: athletes, doping, olympic, ioc, games, olympics, compete, sport, wada, anti doping
# Topic 3: azerbaijan, armenia, karabakh, armenian, nagorno, nagorno karabakh, pashinyan, azerbaijani, ceasefire, yerevan
# Topic 4: korea, north korea, kim, korean, pyongyang, north korean, weapons, jong, kim jong, arms
# Topic 5: vaccine, covid, covid 19, sputnik, infections, virus, vaccination, patients, vaccines, vaccinated
# Topic 6: wagner, prigozhin, bakhmut, mercenary, fighters, yevgeny prigozhin, mutiny, mercenaries, prigozhin said, libya
# Topic 7: nuclear, navalny, court, billion, opposition, bank, nato, eu, weapons, attacks

# %%
topic_model.set_topic_labels({-1: "politics",
                              0: "sports",
                              1: "conflict",
                              2: "conflict",
                              3: "health",
                              4: "conflict",
                              5: "politics"})

# %%
topic_model.visualize_topics(custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2ab6abd-91aa-4376-86b9-30d71e0c6378" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2ab6abd-91aa-4376-86b9-30d71e0c6378")) {                    Plotly.newPlot(                        "c2ab6abd-91aa-4376-86b9-30d71e0c6378",                        [{"customdata":[[0,"sports",214],[1,"conflict",160],[2,"conflict",163],[3,"health",919],[4,"conflict",363],[5,"politics",13737]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[214,160,163,919,363,13737],"sizemode":"area","sizeref":8.585625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[6.912951946258545,6.249859809875488,9.28815746307373,7.306962490081787,9.459866523742676,6.037385940551758],"xaxis":"x","y":[17.775354385375977,18.219839096069336,23.296266555786133,20.48979949951172,20.909448623657227,17.47779655456543],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}," ...

# %%
topic_model.visualize_hierarchy(custom_labels=True, width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fb84d5f6-7224-4a7f-aa30-3ba85b7102e4" class="plotly-graph-div" style="height:290px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb84d5f6-7224-4a7f-aa30-3ba85b7102e4")) {                    Plotly.newPlot(                        "fb84d5f6-7224-4a7f-aa30-3ba85b7102e4",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7556188375637,0.7556188375637,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7556188375637,0.9079922715085648,0.9079922715085648,0.0],"xaxis":"x","y":[-20.0,-20.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.968942871708139,0.968942871708139,0.9079922715085648],"xaxis":"x","y":[-5.0,-5.0,-27.5,-27.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9867581753668888,0.9867581753668888,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.968942871708139,1.0025366588246027,1.0025366588246027,0.9867581753668888],"xaxis":"x","y":[-16.25,-16.25,-50.0,-50.0],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":290,"hovermode":"closest","showlegend":false,"width":600,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["conflict","conflict","politics","health","sports","conflict"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0],"type":"linear","zeroline":false,"range":[-60.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                    Name CustomName  \
# 0     -1    516        -1_yandex_court_griner_witnesses   politics
# 1      0    214           0_athletes_doping_olympic_ioc     sports
# 2      1    160  1_azerbaijan_armenia_karabakh_armenian   conflict
# 3      2    163          2_korea_north korea_kim_korean   conflict
# 4      3    919        3_vaccine_covid_covid 19_sputnik     health
# 5      4    363    4_wagner_prigozhin_bakhmut_mercenary   conflict
# 6      5  13737         5_nuclear_navalny_court_billion   politics
#
#                                       Representation  \
# 0  [yandex, court, griner, witnesses, jehovahs, i...
# 1  [athletes, doping, olympic, ioc, games, olympi...
# 2  [azerbaijan, armenia, karabakh, armenian, nago...
# 3  [korea, north korea, kim, korean, pyongyang, n...
# 4  [vaccine, covid, covid 19, sputnik, infections...
# 5  [wagner, prigozhin, bakhmut, mercenary, fighte...
# 6  [nuclear, navalny, court, billion, opposition,...
#
#                                  Representative_Docs
# 0  [Danish national Dennis Christensen was arrest...
# 1  [Russian athletes have won a total of 25 medal...
# 2  [Six Armenian soldiers were captured by Azerba...
# 3  [North Korean leader Kim Jong Un plans to trav...
# 4  [In early October, as the second wave of Russi...
# 5  [Belarus said on Friday that fighters from the...
# 6  [A Ukrainian attack on a strategic shipyard ea...

# %%
topic_model.visualize_heatmap(custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9a82ec35-b13d-4c12-bad5-1527748eb91e" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a82ec35-b13d-4c12-bad5-1527748eb91e")) {                    Plotly.newPlot(                        "9a82ec35-b13d-4c12-bad5-1527748eb91e",                        [{"coloraxis":"coloraxis","name":"0","x":["sports","conflict","conflict","health","conflict","politics"],"y":["sports","conflict","conflict","health","conflict","politics"],"z":[[1.000000238418579,0.5080183744430542,0.41319146752357483,0.5343036651611328,0.5034632086753845,0.7014837265014648],[0.5080183744430542,0.9999998807907104,0.50022292137146,0.4563145637512207,0.577828049659729,0.7080668210983276],[0.41319146752357483,0.50022292137146,0.9999998807907104,0.40440064668655396,0.5565197467803955,0.6547280550003052],[0.5343036651611328,0.4563145637512207,0.40440064668655396,0.9999998807907104,0.4813011884689331,0.6968114972114563],[0.5034632086753845,0.577828049659729,0.5565197467803955,0.4813011884689331,1.0,0.8014892339706421],[0.7014837265014648,0.7080668210983276,0.6547280550003052,0.6968114972114563,0.8014892339706421,0.9999997615814209]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888, ...

# %% [markdown]
# ### Inference

# %%
df = pd.read_csv(INFERENCE_RUSSIA_FILE_PATH)

# %%
x = topic_model.transform(df.maintext)
# Out:
# Batches:   0%|          | 0/125 [00:00<?, ?it/s]
# 2023-12-04 01:53:36,864 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2023-12-04 01:53:41,393 - BERTopic - Dimensionality - Completed ✓
# 2023-12-04 01:53:41,394 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2023-12-04 01:53:41,826 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2023-12-04 01:53:42,714 - BERTopic - Probabilities - Completed ✓
# 2023-12-04 01:53:42,715 - BERTopic - Cluster - Completed ✓

# %%
df["topic"] = [topic_model.get_topic_info(i).CustomName[0] for i in x[0]]

# %%
df.topic.value_counts()
# Out:
# politics    3575
# conflict     226
# health       142
# sports        57
# Name: topic, dtype: int64

# %%
df.to_csv(INFERENCE_RUSSIA_FILE_PATH, index=False)

# %%
del df_russia, df, topic_model, embeddings, x
